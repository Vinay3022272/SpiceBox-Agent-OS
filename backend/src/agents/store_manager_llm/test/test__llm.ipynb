# %%
import sys
backend_path = r"C:\Users\ps302\OneDrive\Desktop\Razorpay\backend"
sys.path.insert(0, backend_path)

# %%
path = os.path.abspath("../../../../")
print(path)
sys.path.insert(0, path)
# Out:
# c:\Users\ps302\OneDrive\Desktop\Razorpay\backend

# %%
# import sys
import os
print(os.getcwd())
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), "..")))
from src.agents.store_manager_llm.utils.llm import call_llm

response = call_llm(
    "Say hello in one sentence.",
    system="You are a helpful assistant."
)

print(response)
# Out:
# c:\Users\ps302\OneDrive\Desktop\Razorpay\backend\src\agents\store_manager_llm\temp
# Hello!
