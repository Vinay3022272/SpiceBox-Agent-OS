# %%
import sys
import os
project_root = os.path.abspath("../../../../../")
print("Project Root:", project_root)
os.chdir(project_root)
# Add backend to sys.path
backend_path = os.path.join(project_root, "backend")
if backend_path not in sys.path:
    sys.path.insert(0, backend_path)
# Out:
# Project Root: c:\Users\ps302\OneDrive\Desktop\Razorpay

# %%
from src.agents.store_manager_llm import query_wiki

result = query_wiki(
    query="What is the price and rating of iPhone 15?",
    wiki_base_path="./backend/merchant_knowledge",
    merchant_id="23CE31010"
)

print("Answer:\n", result["answer"])
print("Cited Sources:\n", result["sources"])
# Out:
# Answer:
#  **iPhone 15 (Apple)**
#
# | Detail | Information |
# |--------|-------------|
# | **Price** | **79,900 INR** |
# | **Overall Rating** | **4.2 / 5** (based on 5 customer reviews) |
#
# *Source: iPhone 15 product page in the store knowledge base*【knowledge/products/iphone-15.md】.
# Cited Sources:
#  ['knowledge/products/iphone-15.md', 'knowledge/products/iphone-15-pro.md', 'index.md', 'knowledge/products/oneplus-12.md', 'knowledge/index.md']
